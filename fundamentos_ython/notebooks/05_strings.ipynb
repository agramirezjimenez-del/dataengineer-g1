# %%
codigo = "V-2024-1001"
sufijo = "BANK"

# %% [markdown]
# ### Concatenación

# %%
codigo + "-" +sufijo
# Out:
# 'V-2024-1001-BANK'

# %% [markdown]
# ### índice y slicing

# %%
codigo = "V-2024-1001"
codigo[0]
# Out:
# 'V'

# %%
codigo[6]
# Out:
# '-'

# %%
codigo[-1]
# Out:
# '1'

# %%
codigo = "V-2024-1001"

# %%
codigo[1:4]
# Out:
# '-20'

# %%
codigo[:3]
# Out:
# 'V-2'

# %%
# inversion de cadena
codigo[::-1]
# Out:
# '1001-4202-V'

# %% [markdown]
# ### Métodos de limpieza

# %%
nombre = "Ana            Torres   "
apellido_materno = "Gonzalez"

print(f"Número de caracteres: {len(nombre)}")
print(f"Número de caracteres: {len(apellido_materno)}")
# Out:
# Número de caracteres: 24
# Número de caracteres: 8

# %%
print(len(nombre.strip()))
# Out:
# 21

# %%
print(nombre.lower())
# Out:
# ana            torres

# %%
print(nombre.upper())
# Out:
# ANA            TORRES

# %%
print(nombre.title())
# Out:
# Ana            Torres

# %%
nombre.replace("TORRES"," GARCIA")
# Out:
# 'Ana            Torres   '

# %%
nombre.replace(" ","").replace("aT","a T").title()
# Out:
# 'Ana Torres'

# %%
nombre.split()
# Out:
# ['Ana', 'Torres']

# %%
" ".join(nombre.split())
# Out:
# 'Ana Torres'

# %%
" ".join(nombre.split()).title()
# Out:
# 'Ana Torres'

# %%
nombre = "AnaxxTorres"
",".join(nombre.split("xx"))
# Out:
# 'Ana,Torres'

# %%
codigo = "V-2024-1001"

codigo.startswith("V-20")
# Out:
# True

# %%
codigo.startswith("X")
# Out:
# False

# %%
codigo.endswith("1")
# Out:
# True

# %%
codigo.endswith("6")
# Out:
# False

# %%
reporte = "informe_2025.csv"

reporte.endswith(".csv")
# Out:
# True

# %% [markdown]
# ### Regex

# %%
import re

nombre = "AnA            TORRES   "
nombre_limpio = re.sub(r"\s+", " ", nombre).strip().title()
print(f"'{nombre_limpio}'")
# Out:
# 'Ana Torres'
