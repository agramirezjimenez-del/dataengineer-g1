# %% [markdown]
# ### TIPOS DE VARIABLES

# %%
cantidad: int = 3
precio: float = 145.0
cliente: str = "Marco Torres"
activo: bool = True
descuento: None = None

# %%
print("Tipo de la variable cantidad: ", type(cantidad))
print("Tipo de la variable precio: ", type(precio))
print("Tipo de la variable descuento: ", type(descuento))
# Out:
# Tipo de la variable cantidad:  <class 'int'>
# Tipo de la variable precio:  <class 'int'>
# Tipo de la variable descuento:  <class 'NoneType'>

# %% [markdown]
# ### CASTEO DE VARIABLES

# %%
cantidad = "3"
print(type(cantidad))

cantidad = int(cantidad)
print(type(cantidad))

precio = "130.5"
precio = float(precio)
print(type(precio))
print(precio)

precio =  int(precio)
print(precio)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 130.5
# 130
# 0
# False

# %%
activo = 0
print(activo)
activo = bool(activo)
print(activo)
# Out:
# 0
# False

# %%
activo = -1000
print(activo)

activo = bool(activo)
print(activo)
# Out:
# -1000
# True

# %%
activo =  ""
activo = bool(activo)
print(activo)
# Out:
# False

# %%
activo =  "True"
activo = bool(activo)
print(activo)
# Out:
# True

# %%
activo =  "False"
activo = bool(activo)
print(activo)
# Out:
# True

# %%
precio = 3.5
precio = int(precio)
print(precio)
# Out:
# 3
