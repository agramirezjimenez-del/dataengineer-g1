# %%
mi_nombre = "Gaby"

print(f"Me llamo: {mi_nombre}")
# Out:
# Me llamo: Gaby

# %%
cliente = "Ana Torres"
total = 6000.555555

print(f"El cliente {cliente} tiene un total de: {total}")
print(f"El cliente {cliente} | total: {total}")
print(f"El cliente {cliente} | total: {total*2}*2")
print(f"El cliente {cliente} | total: {total*2:.2f}")
# Out:
# El cliente Ana Torres tiene un total de: 6000.555555
# El cliente Ana Torres | total: 6000.555555
# El cliente Ana Torres | total: 12001.11111*2
# El cliente Ana Torres | total: 12001.11
