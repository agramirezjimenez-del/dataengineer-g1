# %%
cantidad = 20

# %%
cantidad > 0

# %%
cantidad < 0

# %%
cantidad  >= 20

# %%
cantidad <= 10

# %%
ciudad_1 = "Arequipa"
ciudad_2 = "Lima"

ciudad_1 == ciudad_2

# %%
ciudad_1 == "Arequipa"

# %%
ciudad_1 != "Arequipa"

# %%
ciudad_2 != "Arequipa"

# %%
cantidad = 20
precio = 10

cantidad > 5 and precio > 10

# %%
es_valido = False
not es_valido

# %%
identificador = None

#identificador == None 
identificador is None
